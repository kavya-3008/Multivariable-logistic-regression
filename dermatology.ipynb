# %%
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install seaborn
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install scikit-learn
# Out:
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install plotly
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 4.1 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import plotly.express as px
import plotly.graph_objects as go

# %%
data = pd.read_csv('/Users/kavya/Downloads/untitled folder/dermatology_database_1.csv')
data
# Out:
#      erythema  scaling  definite_borders  itching  koebner_phenomenon  \
# 0           2        2                 0        3                   0
# 1           3        3                 3        2                   1
# 2           2        1                 2        3                   1
# 3           2        2                 2        0                   0
# 4           2        3                 2        2                   2
# ..        ...      ...               ...      ...                 ...
# 361         2        1                 1        0                   1
# 362         3        2                 1        0                   1
# 363         3        2                 2        2                   3
# 364         2        1                 3        1                   2
# 365         3        2                 2        0                   0
#
#      polygonal_papules  follicular_papules  oral_mucosal_involvement  \
# ...

# %%
data.describe()
# Out:
#          erythema     scaling  definite_borders     itching  \
# count  366.000000  366.000000        366.000000  366.000000
# mean     2.068306    1.795082          1.549180    1.366120
# std      0.664753    0.701527          0.907525    1.138299
# min      0.000000    0.000000          0.000000    0.000000
# 25%      2.000000    1.000000          1.000000    0.000000
# 50%      2.000000    2.000000          2.000000    1.000000
# 75%      2.000000    2.000000          2.000000    2.000000
# max      3.000000    3.000000          3.000000    3.000000
#
#        koebner_phenomenon  polygonal_papules  follicular_papules  \
# count          366.000000         366.000000          366.000000
# mean             0.633880           0.448087            0.166667
# std              0.908016           0.957327            0.570588
# min              0.000000           0.000000            0.000000
# 25%              0.000000           0.000000            0.000000
# ...

# %% [markdown]
# Class distribution data visualisation

# %%
targetvalue = data['class'].value_counts()
fig, ax = plt.subplots()
ax.pie(targetvalue.values, labels=targetvalue.index, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title('Class Distribution')

plt.show()

# %% [markdown]
# Converting the age into numeric value

# %%
data['age'] = pd.to_numeric(data['age'], errors='coerce')

# %%
#check for and remove null data 
data.dropna(inplace = True)

# %% [markdown]
# data visualisation of the class(target value)'s distribution.

# %%
targetvalue.plot(kind='bar',color = 'pink',edgecolor='black')

plt.xlabel('Class')
plt.ylabel('Frequency')
plt.title('Frequency of Each Class')
# Out:
# Text(0.5, 1.0, 'Frequency of Each Class')

# %%
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier 
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report

# %% [markdown]
# Splitting the data into x and y and training and testing and then using machine learning models to give the output.

# %%
x = data.drop('class',axis=1)
y = data['class']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# carry out logistic regression

# %%
model = LogisticRegression(max_iter=10000)
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=10000)

# %%
y_pred = model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)
report = classification_report(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print(f'Confusion Matrix:\n{cm}')
print(f'Classification Report:\n{report}')
# Out:
# Accuracy: 0.9583333333333334
# Confusion Matrix:
# [[22  0  0  0  0  0]
#  [ 0 12  0  2  0  0]
#  [ 0  0 13  1  0  0]
#  [ 0  0  0  8  0  0]
#  [ 0  0  0  0 12  0]
#  [ 0  0  0  0  0  2]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        22
#            2       1.00      0.86      0.92        14
#            3       1.00      0.93      0.96        14
#            4       0.73      1.00      0.84         8
#            5       1.00      1.00      1.00        12
#            6       1.00      1.00      1.00         2
#
#     accuracy                           0.96        72
#    macro avg       0.95      0.96      0.95        72
# weighted avg       0.97      0.96      0.96        72

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# An accuracy of 0.9583 indicates that the model correctly predicts the class labels for 95% of the instances. This is generally a good accuracy, suggesting that the model performs well on the given dataset.

# %% [markdown]
# Confusion Matrix Analysis
# The confusion matrix shows the true positive, false positive, true negative, and false negative values for each class:
#
# Class 1: Perfectly classified with no misclassifications.
#
# Class 2: Misclassified 2 instances as another class.
#
# Class 3: Misclassified 1 instance as another class.
#
# Class 4: Perfectly classified with no misclassifications.
#
# Class 5: Perfectly classified with no misclassifications.
#
# Class 6: Perfectly classified with no misclassifications.

# %% [markdown]
# Precision: The model demonstrates high precision across all classes, with precision values ranging from 0.73 to 1.00. This indicates that when the model predicts a class, it is very likely to be correct.
#
# Recall: Recall values are also high, ranging from 0.86 to 1.00, indicating that the model successfully identifies a large proportion of actual positives.
#
# F1-Score: The F1-scores, which balance precision and recall, are high for all classes, ranging from 0.84 to 1.00. This suggests a good balance between precision and recall for the model.
#
# Macro Average: Averages the precision, recall, and F1-score without considering the class imbalance, showing high and consistent performance across all classes.
#
# Weighted Average: Averages these metrics while considering the support (the number of true instances for each label), showing an overall high performance for the model.

# %% [markdown]
# The logistic regression model performs exceptionally well, with an accuracy of 95.8%, indicating that it correctly predicts the class labels for the vast majority of instances. The confusion matrix shows minimal misclassifications, and the classification report highlights high precision, recall, and F1-scores across all classes.
